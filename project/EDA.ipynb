# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe = pd.read_csv('cardio_train.csv',sep=";")
dataframe.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
dataframe.shape
# Out:
# (70000, 13)

# %%
dataframe.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
dataframe.dtypes
# Out:
# id               int64
# age              int64
# gender           int64
# height           int64
# weight         float64
# ap_hi            int64
# ap_lo            int64
# cholesterol      int64
# gluc             int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# dtype: object

# %%
dataframe.nunique()
# Out:
# id             70000
# age             8076
# gender             2
# height           109
# weight           287
# ap_hi            153
# ap_lo            157
# cholesterol        3
# gluc               3
# smoke              2
# alco               2
# active             2
# cardio             2
# dtype: int64

# %%
dataframe['ap_hi'].value_counts()
# Out:
# ap_hi
#  120     27699
#  140      9506
#  130      8961
#  110      8644
#  150      4450
#          ...
#  1620        1
#  199         1
# -150         1
# -115         1
#  2000        1
# Name: count, Length: 153, dtype: int64

# %%
dataframe.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
sns.countplot(x = 'cardio' , data = dataframe)
# Out:
# <Axes: xlabel='cardio', ylabel='count'>

# %%
plt.subplot(1, 2, 1)
sns.boxplot(x=dataframe['height'])
plt.subplot(1, 2, 2)
sns.boxplot(x=dataframe['weight'], color='orange')
# Out:
# <Axes: xlabel='weight'>

# %%
plt.figure(figsize=(10,8))

sns.heatmap(dataframe.corr(),cmap='coolwarm', annot=True,fmt='0.2f')
# Out:
# <Axes: >

# %%
data = dataframe.drop(columns=['id'])
data.head()
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  18393       2     168    62.0    110     80            1     1      0
# 1  20228       1     156    85.0    140     90            3     1      0
# 2  18857       1     165    64.0    130     70            3     1      0
# 3  17623       2     169    82.0    150    100            1     1      0
# 4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
data.duplicated().sum()
# Out:
# np.int64(24)

# %%
data = data.drop_duplicates()
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# ...

# %%
data['age'] = (data['age']//365.25).astype(int)

data
# Out:
#        age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0       50       2     168    62.0    110     80            1     1      0
# 1       55       1     156    85.0    140     90            3     1      0
# 2       51       1     165    64.0    130     70            3     1      0
# 3       48       2     169    82.0    150    100            1     1      0
# 4       47       1     156    56.0    100     60            1     1      0
# ...    ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995   52       2     168    76.0    120     80            1     1      1
# 69996   61       1     158   126.0    140     90            2     2      0
# 69997   52       2     183   105.0    180     90            3     1      0
# 69998   61       1     163    72.0    135     80            1     2      0
# 69999   56       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# 0         0       1       0
# ...

# %%
data.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  69976.000000  69976.000000  69976.000000  69976.000000  69976.000000
# mean      52.803475      1.349648    164.359152     74.208519    128.820453
# std        6.762773      0.476862      8.211218     14.397211    154.037729
# min       29.000000      1.000000     55.000000     10.000000   -150.000000
# 25%       48.000000      1.000000    159.000000     65.000000    120.000000
# 50%       53.000000      1.000000    165.000000     72.000000    120.000000
# 75%       58.000000      2.000000    170.000000     82.000000    140.000000
# max       64.000000      2.000000    250.000000    200.000000  16020.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  69976.000000  69976.000000  69976.000000  69976.000000  69976.000000
# mean      96.636261      1.366997      1.226535      0.088159      0.053790
# ...

# %%
print((data.weight>=150).sum())
print((data.height>=200).sum())
##remove or not
# Out:
# 73
# 3

# %%
## 50 300 high >low
data = data[
    (data['ap_hi'] >= 50) & (data['ap_hi'] <= 250) &
    (data['ap_lo'] >= 30) & (data['ap_lo'] <= 150) &
    (data['ap_hi'] > data['ap_lo'])
]

data
# Out:
#        age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0       50       2     168    62.0    110     80            1     1      0
# 1       55       1     156    85.0    140     90            3     1      0
# 2       51       1     165    64.0    130     70            3     1      0
# 3       48       2     169    82.0    150    100            1     1      0
# 4       47       1     156    56.0    100     60            1     1      0
# ...    ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995   52       2     168    76.0    120     80            1     1      1
# 69996   61       1     158   126.0    140     90            2     2      0
# 69997   52       2     183   105.0    180     90            3     1      0
# 69998   61       1     163    72.0    135     80            1     2      0
# 69999   56       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# 0         0       1       0
# ...

# %%
data.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  68649.000000  68649.000000  68649.000000  68649.000000  68649.000000
# mean      52.791592      1.348701    164.361025     74.121597    126.671474
# std        6.765119      0.476563      8.184789     14.333371     16.684950
# min       29.000000      1.000000     55.000000     11.000000     60.000000
# 25%       48.000000      1.000000    159.000000     65.000000    120.000000
# 50%       53.000000      1.000000    165.000000     72.000000    120.000000
# 75%       58.000000      2.000000    170.000000     82.000000    140.000000
# max       64.000000      2.000000    250.000000    200.000000    240.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  68649.000000  68649.000000  68649.000000  68649.000000  68649.000000
# mean      81.297004      1.364739      1.225743      0.087998      0.053373
# ...
